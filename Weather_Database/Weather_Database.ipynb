# %%
#import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

coordinates = list(lat_lngs)
coordinates
    
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
#Loop through all the cities in our list
for i, city in enumerate(cities):
    
    #Group cities in sets of 50 for logging purposes
    if (i%50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
    
    #Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass


# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 2 of Set 1 | nanortalik
# Processing Record 3 of Set 1 | puerto ayora
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | kapaa
# Processing Record 6 of Set 1 | onomichi
# Processing Record 7 of Set 1 | comodoro rivadavia
# Processing Record 8 of Set 1 | mataura
# Processing Record 9 of Set 1 | bredasdorp
# Processing Record 10 of Set 1 | pangody
# Processing Record 11 of Set 1 | zhuhai
# Processing Record 12 of Set 1 | saldanha
# Processing Record 13 of Set 1 | new norfolk
# Processing Record 14 of Set 1 | kavieng
# Processing Record 15 of Set 1 | marawi
# Processing Record 16 of Set 1 | san patricio
# Processing Record 17 of Set 1 | avarua
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | cape town
# Processing Record 20 of Set 1 | bluff
# Processing Record 21 of Set 1 | vaini
# Processing Record 22 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 23 of Set 1 | vila franca do campo
# Processing Record 24 of Set 1 | karratha
# Processing Record 25 of Set 1 | cockburn town
# Processing Record 26 of Set 1 | meulaboh
# Processing Record 27 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 1 | okoneshnikovo
# Processing Record 29 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 1 | haines junction
# Processing Record 31 of Set 1 | korla
# Processing Record 32 of Set 1 | vestmannaeyjar
# Processing Record 33 of Set 1 | castro
# Processing Record 34 of Set 1 | bedele
# Processing Record 35 of Set 1 | torbay
# Processing Record 36 of Set 1 | sawakin
# Processing Record 37 of Set 1 | barrow
# Processing Record 38 of Set 1 | kasungu
# Processing Record 39 of Set 1 | mangaratiba
# Processing Record 40 of Set 1 | merauke
# Processing Record 41 of Set 1 | mehamn
# Processing Record 42 of Set 1 | kajaani
# Processing Record 43 of Set 1 | mahebourg
# Processing Record 44 of Set 1 | hermanus
# Processing Record 45 of Set 1 | amga
# Processing Record 46 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 1 | los llanos de aridane
# Processing Record 48 of Set 1 | ushuaia
# Processing Record 49 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 1 | tiksi
# Processing Record 1 of Set 2 | bonfim
# Processing Record 2 of Set 2 | kruisfontein
# Processing Record 3 of Set 2 | mirina
# City not found. Skipping...
# Processing Record 4 of Set 2 | qaanaaq
# Processing Record 5 of Set 2 | punta arenas
# Processing Record 6 of Set 2 | constitucion
# Processing Record 7 of Set 2 | kiruna
# Processing Record 8 of Set 2 | puerto escondido
# Processing Record 9 of Set 2 | hobart
# Processing Record 10 of Set 2 | tasiilaq
# Processing Record 11 of Set 2 | tuktoyaktuk
# Processing Record 12 of Set 2 | tezu
# Processing Record 13 of Set 2 | forquilhinha
# Processing Record 14 of Set 2 | riyadh
# Processing Record 15 of Set 2 | belem de sao francisco
# Processing Record 16 of Set 2 | jeremie
# Processing Record 17 of Set 2 | sesheke
# Processing Record 18 of Set 2 | stephenville
# Processing Record 19 of Set 2 | sao filipe
# Processing Record 20 of Set 2 | ahuimanu
# Processing Record 21 of Set 2 | xudat
# Processing Record 22 of Set 2 | namibe
# Processing Record 23 of Set 2 | touros
# Processing Record 24 of Set 2 | port hardy
# Processing Record 25 of Set 2 | kodiak
# Processing Record 26 of Set 2 | mirabad
# Processing Record 27 of Set 2 | victoria
# Processing Record 28 of Set 2 | bubaque
# Processing Record 29 of Set 2 | antibes
# Processing Record 30 of Set 2 | maroantsetra
# Processing Record 31 of Set 2 | kalas
# Processing Record 32 of Set 2 | hlotse
# Processing Record 33 of Set 2 | nyurba
# Processing Record 34 of Set 2 | upernavik
# Processing Record 35 of Set 2 | nabire
# Processing Record 36 of Set 2 | gurskoye
# City not found. Skipping...
# Processing Record 37 of Set 2 | lorengau
# Processing Record 38 of Set 2 | naze
# Processing Record 39 of Set 2 | esperance
# Processing Record 40 of Set 2 | jamestown
# Processing Record 41 of Set 2 | airai
# Processing Record 42 of Set 2 | sioux lookout
# Processing Record 43 of Set 2 | chumikan
# Processing Record 44 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 45 of Set 2 | butaritari
# Processing Record 46 of Set 2 | albany
# Processing Record 47 of Set 2 | lethem
# Processing Record 48 of Set 2 | umm kaddadah
# Processing Record 49 of Set 2 | saint-philippe
# Processing Record 50 of Set 2 | asau
# Processing Record 1 of Set 3 | bayan
# Processing Record 2 of Set 3 | macheng
# Processing Record 3 of Set 3 | atuona
# Processing Record 4 of Set 3 | havre
# Processing Record 5 of Set 3 | kaitangata
# Processing Record 6 of Set 3 | pangnirtung
# Processing Record 7 of Set 3 | narrabri
# Processing Record 8 of Set 3 | nanyang
# Processing Record 9 of Set 3 | banikoara
# Processing Record 10 of Set 3 | maniitsoq
# Processing Record 11 of Set 3 | ilulissat
# Processing Record 12 of Set 3 | lebu
# Processing Record 13 of Set 3 | dingle
# Processing Record 14 of Set 3 | laguna
# Processing Record 15 of Set 3 | houma
# Processing Record 16 of Set 3 | hilo
# Processing Record 17 of Set 3 | lavrentiya
# Processing Record 18 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 3 | bathsheba
# Processing Record 20 of Set 3 | isangel
# Processing Record 21 of Set 3 | mandalgovi
# Processing Record 22 of Set 3 | east london
# Processing Record 23 of Set 3 | jacareacanga
# Processing Record 24 of Set 3 | naron
# Processing Record 25 of Set 3 | yellowknife
# Processing Record 26 of Set 3 | quatre cocos
# Processing Record 27 of Set 3 | te anau
# Processing Record 28 of Set 3 | huazolotitlan
# City not found. Skipping...
# Processing Record 29 of Set 3 | khatanga
# Processing Record 30 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 31 of Set 3 | sitka
# Processing Record 32 of Set 3 | maloshuyka
# City not found. Skipping...
# Processing Record 33 of Set 3 | sept-iles
# Processing Record 34 of Set 3 | ambulu
# Processing Record 35 of Set 3 | walvis bay
# Processing Record 36 of Set 3 | zharkent
# Processing Record 37 of Set 3 | atambua
# Processing Record 38 of Set 3 | maldonado
# Processing Record 39 of Set 3 | hoima
# Processing Record 40 of Set 3 | monrovia
# Processing Record 41 of Set 3 | santa fe
# Processing Record 42 of Set 3 | pingliang
# Processing Record 43 of Set 3 | kilindoni
# Processing Record 44 of Set 3 | mwanza
# Processing Record 45 of Set 3 | bethel
# Processing Record 46 of Set 3 | sosnovoborsk
# Processing Record 47 of Set 3 | ulladulla
# Processing Record 48 of Set 3 | youkounkoun
# Processing Record 49 of Set 3 | alofi
# Processing Record 50 of Set 3 | nyanguge
# Processing Record 1 of Set 4 | mossendjo
# Processing Record 2 of Set 4 | nalut
# Processing Record 3 of Set 4 | waingapu
# Processing Record 4 of Set 4 | yar-sale
# Processing Record 5 of Set 4 | zhanaozen
# Processing Record 6 of Set 4 | norman wells
# Processing Record 7 of Set 4 | cherskiy
# Processing Record 8 of Set 4 | leningradskiy
# Processing Record 9 of Set 4 | tura
# Processing Record 10 of Set 4 | ponta do sol
# Processing Record 11 of Set 4 | arraial do cabo
# Processing Record 12 of Set 4 | portland
# Processing Record 13 of Set 4 | palauig
# Processing Record 14 of Set 4 | mabopane
# Processing Record 15 of Set 4 | talcahuano
# Processing Record 16 of Set 4 | payo
# Processing Record 17 of Set 4 | avera
# Processing Record 18 of Set 4 | fortuna
# Processing Record 19 of Set 4 | santa marta
# Processing Record 20 of Set 4 | chudovo
# Processing Record 21 of Set 4 | vardo
# Processing Record 22 of Set 4 | terra santa
# Processing Record 23 of Set 4 | alice springs
# Processing Record 24 of Set 4 | russell
# Processing Record 25 of Set 4 | hai duong
# Processing Record 26 of Set 4 | carnarvon
# Processing Record 27 of Set 4 | vao
# Processing Record 28 of Set 4 | mayumba
# Processing Record 29 of Set 4 | lagos
# Processing Record 30 of Set 4 | cabedelo
# Processing Record 31 of Set 4 | sibolga
# Processing Record 32 of Set 4 | faanui
# Processing Record 33 of Set 4 | sonepur
# Processing Record 34 of Set 4 | lewistown
# Processing Record 35 of Set 4 | ternate
# Processing Record 36 of Set 4 | colombia
# Processing Record 37 of Set 4 | miranda
# Processing Record 38 of Set 4 | goderich
# Processing Record 39 of Set 4 | tabialan
# City not found. Skipping...
# Processing Record 40 of Set 4 | georgetown
# Processing Record 41 of Set 4 | urengoy
# Processing Record 42 of Set 4 | hualmay
# Processing Record 43 of Set 4 | bambous virieux
# Processing Record 44 of Set 4 | hovd
# Processing Record 45 of Set 4 | inirida
# Processing Record 46 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 47 of Set 4 | nisia floresta
# Processing Record 48 of Set 4 | halifax
# Processing Record 49 of Set 4 | awbari
# Processing Record 50 of Set 4 | general roca
# Processing Record 1 of Set 5 | evensk
# Processing Record 2 of Set 5 | cap malheureux
# Processing Record 3 of Set 5 | qianan
# Processing Record 4 of Set 5 | port blair
# Processing Record 5 of Set 5 | bahia blanca
# Processing Record 6 of Set 5 | ostrovnoy
# Processing Record 7 of Set 5 | bethanien
# Processing Record 8 of Set 5 | chuy
# Processing Record 9 of Set 5 | abidjan
# Processing Record 10 of Set 5 | lompoc
# Processing Record 11 of Set 5 | zambezi
# Processing Record 12 of Set 5 | port alfred
# Processing Record 13 of Set 5 | dikson
# Processing Record 14 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 15 of Set 5 | nome
# Processing Record 16 of Set 5 | bambanglipuro
# Processing Record 17 of Set 5 | nikolskoye
# Processing Record 18 of Set 5 | longyearbyen
# Processing Record 19 of Set 5 | kilemary
# Processing Record 20 of Set 5 | redmond
# Processing Record 21 of Set 5 | nemuro
# Processing Record 22 of Set 5 | namtsy
# Processing Record 23 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 24 of Set 5 | zavetnoye
# Processing Record 25 of Set 5 | san cristobal
# Processing Record 26 of Set 5 | saint anthony
# Processing Record 27 of Set 5 | mineros
# Processing Record 28 of Set 5 | ambon
# Processing Record 29 of Set 5 | coahuayana
# Processing Record 30 of Set 5 | utena
# Processing Record 31 of Set 5 | nipawin
# Processing Record 32 of Set 5 | ormara
# Processing Record 33 of Set 5 | cidreira
# Processing Record 34 of Set 5 | paamiut
# Processing Record 35 of Set 5 | mezen
# Processing Record 36 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 37 of Set 5 | kariba
# Processing Record 38 of Set 5 | tornio
# Processing Record 39 of Set 5 | bukama
# Processing Record 40 of Set 5 | gravdal
# Processing Record 41 of Set 5 | thompson
# Processing Record 42 of Set 5 | price
# Processing Record 43 of Set 5 | severo-kurilsk
# Processing Record 44 of Set 5 | geraldton
# Processing Record 45 of Set 5 | mayo
# Processing Record 46 of Set 5 | koumac
# Processing Record 47 of Set 5 | tawkar
# City not found. Skipping...
# Processing Record 48 of Set 5 | khani
# Processing Record 49 of Set 5 | sola
# Processing Record 50 of Set 5 | krasne
# Processing Record 1 of Set 6 | borovichi
# Processing Record 2 of Set 6 | griffith
# Processing Record 3 of Set 6 | cookshire
# City not found. Skipping...
# Processing Record 4 of Set 6 | pevek
# Processing Record 5 of Set 6 | nelson bay
# Processing Record 6 of Set 6 | ballina
# Processing Record 7 of Set 6 | poum
# Processing Record 8 of Set 6 | camacha
# Processing Record 9 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 10 of Set 6 | warangal
# Processing Record 11 of Set 6 | khandyga
# Processing Record 12 of Set 6 | tunduru
# City not found. Skipping...
# Processing Record 13 of Set 6 | toora-khem
# Processing Record 14 of Set 6 | gamba
# Processing Record 15 of Set 6 | jujuy
# City not found. Skipping...
# Processing Record 16 of Set 6 | maracacume
# Processing Record 17 of Set 6 | kapit
# Processing Record 18 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 19 of Set 6 | vammala
# Processing Record 20 of Set 6 | chippewa falls
# Processing Record 21 of Set 6 | havre-saint-pierre
# Processing Record 22 of Set 6 | panguna
# Processing Record 23 of Set 6 | utete
# Processing Record 24 of Set 6 | gisborne
# Processing Record 25 of Set 6 | kuito
# Processing Record 26 of Set 6 | taltal
# Processing Record 27 of Set 6 | bilibino
# Processing Record 28 of Set 6 | iranshahr
# Processing Record 29 of Set 6 | port lincoln
# Processing Record 30 of Set 6 | sosva
# Processing Record 31 of Set 6 | okhotsk
# Processing Record 32 of Set 6 | luoyang
# Processing Record 33 of Set 6 | rock sound
# Processing Record 34 of Set 6 | yanan
# City not found. Skipping...
# Processing Record 35 of Set 6 | necochea
# Processing Record 36 of Set 6 | vostok
# Processing Record 37 of Set 6 | aylmer
# Processing Record 38 of Set 6 | basco
# Processing Record 39 of Set 6 | temaraia
# City not found. Skipping...
# Processing Record 40 of Set 6 | port macquarie
# Processing Record 41 of Set 6 | tamandare
# Processing Record 42 of Set 6 | antofagasta
# Processing Record 43 of Set 6 | sinkat
# City not found. Skipping...
# Processing Record 44 of Set 6 | cariamanga
# Processing Record 45 of Set 6 | padang
# Processing Record 46 of Set 6 | derzhavinsk
# Processing Record 47 of Set 6 | cabo san lucas
# Processing Record 48 of Set 6 | taksimo
# Processing Record 49 of Set 6 | rio gallegos
# Processing Record 50 of Set 6 | bagotville
# Processing Record 1 of Set 7 | sungai besar
# Processing Record 2 of Set 7 | chokurdakh
# Processing Record 3 of Set 7 | huarmey
# Processing Record 4 of Set 7 | seoul
# Processing Record 5 of Set 7 | olga
# Processing Record 6 of Set 7 | carahue
# Processing Record 7 of Set 7 | toamasina
# Processing Record 8 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 9 of Set 7 | la maddalena
# Processing Record 10 of Set 7 | ribeira grande
# Processing Record 11 of Set 7 | flin flon
# Processing Record 12 of Set 7 | mandera
# Processing Record 13 of Set 7 | eyl
# Processing Record 14 of Set 7 | emporia
# Processing Record 15 of Set 7 | guerrero negro
# Processing Record 16 of Set 7 | umm durman
# City not found. Skipping...
# Processing Record 17 of Set 7 | port elizabeth
# Processing Record 18 of Set 7 | coihaique
# Processing Record 19 of Set 7 | gat
# Processing Record 20 of Set 7 | pisco
# Processing Record 21 of Set 7 | stamsund
# City not found. Skipping...
# Processing Record 22 of Set 7 | sint-gillis-waas
# Processing Record 23 of Set 7 | byron bay
# Processing Record 24 of Set 7 | chifeng
# Processing Record 25 of Set 7 | kem
# Processing Record 26 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 27 of Set 7 | zhigansk
# Processing Record 28 of Set 7 | egvekinot
# Processing Record 29 of Set 7 | galiwinku
# City not found. Skipping...
# Processing Record 30 of Set 7 | faya
# Processing Record 31 of Set 7 | ukiah
# Processing Record 32 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 33 of Set 7 | oberkirch
# Processing Record 34 of Set 7 | mudyuga
# City not found. Skipping...
# Processing Record 35 of Set 7 | gizo
# Processing Record 36 of Set 7 | ambilobe
# Processing Record 37 of Set 7 | morondava
# Processing Record 38 of Set 7 | lima
# Processing Record 39 of Set 7 | sarankhola
# Processing Record 40 of Set 7 | bazarnyye mataki
# Processing Record 41 of Set 7 | palmer
# Processing Record 42 of Set 7 | trincomalee
# Processing Record 43 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 44 of Set 7 | kang
# Processing Record 45 of Set 7 | fort nelson
# Processing Record 46 of Set 7 | bandarbeyla
# Processing Record 47 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 48 of Set 7 | maues
# Processing Record 49 of Set 7 | pechenga
# Processing Record 50 of Set 7 | auki
# Processing Record 1 of Set 8 | bumba
# Processing Record 2 of Set 8 | port hedland
# Processing Record 3 of Set 8 | rosarito
# Processing Record 4 of Set 8 | plettenberg bay
# Processing Record 5 of Set 8 | katsuura
# Processing Record 6 of Set 8 | bac lieu
# Processing Record 7 of Set 8 | capaci
# Processing Record 8 of Set 8 | tigil
# Processing Record 9 of Set 8 | kijang
# Processing Record 10 of Set 8 | burica
# City not found. Skipping...
# Processing Record 11 of Set 8 | tual
# Processing Record 12 of Set 8 | la palma
# Processing Record 13 of Set 8 | kanel
# Processing Record 14 of Set 8 | nandura
# Processing Record 15 of Set 8 | vestmanna
# Processing Record 16 of Set 8 | erenhot
# Processing Record 17 of Set 8 | havoysund
# Processing Record 18 of Set 8 | oltu
# Processing Record 19 of Set 8 | aki
# Processing Record 20 of Set 8 | san quintin
# Processing Record 21 of Set 8 | muri
# Processing Record 22 of Set 8 | hithadhoo
# Processing Record 23 of Set 8 | mar del plata
# Processing Record 24 of Set 8 | butembo
# Processing Record 25 of Set 8 | kondinskoye
# Processing Record 26 of Set 8 | mantua
# Processing Record 27 of Set 8 | kassala
# Processing Record 28 of Set 8 | hamilton
# Processing Record 29 of Set 8 | grand centre
# City not found. Skipping...
# Processing Record 30 of Set 8 | lancaster
# Processing Record 31 of Set 8 | manokwari
# Processing Record 32 of Set 8 | batticaloa
# Processing Record 33 of Set 8 | winnemucca
# Processing Record 34 of Set 8 | mariental
# Processing Record 35 of Set 8 | hoquiam
# Processing Record 36 of Set 8 | barreiras
# Processing Record 37 of Set 8 | sandwick
# Processing Record 38 of Set 8 | narsaq
# Processing Record 39 of Set 8 | san angelo
# Processing Record 40 of Set 8 | grand gaube
# Processing Record 41 of Set 8 | cayenne
# Processing Record 42 of Set 8 | lamu
# Processing Record 43 of Set 8 | tidore
# City not found. Skipping...
# Processing Record 44 of Set 8 | tuatapere
# Processing Record 45 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 46 of Set 8 | ancud
# Processing Record 47 of Set 8 | vanavara
# Processing Record 48 of Set 8 | moerai
# Processing Record 49 of Set 8 | nanlong
# Processing Record 50 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 1 of Set 9 | mumford
# Processing Record 2 of Set 9 | carutapera
# Processing Record 3 of Set 9 | saint-augustin
# Processing Record 4 of Set 9 | oranjemund
# Processing Record 5 of Set 9 | atasu
# Processing Record 6 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 7 of Set 9 | sinnamary
# Processing Record 8 of Set 9 | porto novo
# Processing Record 9 of Set 9 | krasnoselkup
# Processing Record 10 of Set 9 | little current
# Processing Record 11 of Set 9 | guipavas
# Processing Record 12 of Set 9 | baiyin
# Processing Record 13 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 14 of Set 9 | skjervoy
# Processing Record 15 of Set 9 | saint george
# Processing Record 16 of Set 9 | clyde river
# Processing Record 17 of Set 9 | maloy
# Processing Record 18 of Set 9 | antalaha
# Processing Record 19 of Set 9 | honiara
# Processing Record 20 of Set 9 | weyburn
# Processing Record 21 of Set 9 | acajutla
# Processing Record 22 of Set 9 | ust-kuyga
# Processing Record 23 of Set 9 | staryy nadym
# Processing Record 24 of Set 9 | bogorodskoye
# Processing Record 25 of Set 9 | harlingen
# Processing Record 26 of Set 9 | manthani
# Processing Record 27 of Set 9 | togul
# Processing Record 28 of Set 9 | corinto
# Processing Record 29 of Set 9 | sobolevo
# Processing Record 30 of Set 9 | iqaluit
# Processing Record 31 of Set 9 | port augusta
# Processing Record 32 of Set 9 | raton
# Processing Record 33 of Set 9 | chapleau
# Processing Record 34 of Set 9 | richards bay
# Processing Record 35 of Set 9 | buala
# Processing Record 36 of Set 9 | kahului
# Processing Record 37 of Set 9 | paita
# Processing Record 38 of Set 9 | boyolangu
# Processing Record 39 of Set 9 | amalapuram
# Processing Record 40 of Set 9 | norrtalje
# Processing Record 41 of Set 9 | boa vista
# Processing Record 42 of Set 9 | dagana
# Processing Record 43 of Set 9 | dabola
# Processing Record 44 of Set 9 | bulolo
# Processing Record 45 of Set 9 | yulara
# Processing Record 46 of Set 9 | manihari
# Processing Record 47 of Set 9 | kudahuvadhoo
# Processing Record 48 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 49 of Set 9 | moron
# Processing Record 50 of Set 9 | mungwi
# Processing Record 1 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 2 of Set 10 | shubarshi
# Processing Record 3 of Set 10 | mabaruma
# Processing Record 4 of Set 10 | pershotravneve
# Processing Record 5 of Set 10 | nizwa
# Processing Record 6 of Set 10 | hambantota
# Processing Record 7 of Set 10 | shakawe
# Processing Record 8 of Set 10 | college
# Processing Record 9 of Set 10 | phan thiet
# Processing Record 10 of Set 10 | herat
# Processing Record 11 of Set 10 | mandalgarh
# Processing Record 12 of Set 10 | harper
# Processing Record 13 of Set 10 | taburi
# City not found. Skipping...
# Processing Record 14 of Set 10 | saskylakh
# Processing Record 15 of Set 10 | vigrestad
# Processing Record 16 of Set 10 | klyuchevskiy
# Processing Record 17 of Set 10 | naryan-mar
# Processing Record 18 of Set 10 | pauini
# Processing Record 19 of Set 10 | quelimane
# Processing Record 20 of Set 10 | oktyabrskiy
# Processing Record 21 of Set 10 | lively
# Processing Record 22 of Set 10 | atar
# Processing Record 23 of Set 10 | luena
# Processing Record 24 of Set 10 | ararangua
# Processing Record 25 of Set 10 | arroyo
# Processing Record 26 of Set 10 | waipawa
# Processing Record 27 of Set 10 | namatanai
# Processing Record 28 of Set 10 | petropavlovka
# Processing Record 29 of Set 10 | powell river
# Processing Record 30 of Set 10 | kortkeros
# Processing Record 31 of Set 10 | salinas
# Processing Record 32 of Set 10 | ler
# Processing Record 33 of Set 10 | mastic beach
# Processing Record 34 of Set 10 | roding
# Processing Record 35 of Set 10 | kayes
# Processing Record 36 of Set 10 | dhankuta
# Processing Record 37 of Set 10 | tarrafal
# Processing Record 38 of Set 10 | evansville
# Processing Record 39 of Set 10 | lichtenburg
# Processing Record 40 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 41 of Set 10 | svetlyy
# Processing Record 42 of Set 10 | talnakh
# Processing Record 43 of Set 10 | skalistyy
# City not found. Skipping...
# Processing Record 44 of Set 10 | mercedes
# Processing Record 45 of Set 10 | mundargi
# Processing Record 46 of Set 10 | dudinka
# Processing Record 47 of Set 10 | cooma
# Processing Record 48 of Set 10 | tessalit
# Processing Record 49 of Set 10 | betafo
# Processing Record 50 of Set 10 | moshi
# Processing Record 1 of Set 11 | rundu
# Processing Record 2 of Set 11 | shimoda
# Processing Record 3 of Set 11 | tefe
# Processing Record 4 of Set 11 | rio de janeiro
# Processing Record 5 of Set 11 | lagoa
# Processing Record 6 of Set 11 | jiddah
# City not found. Skipping...
# Processing Record 7 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 11 | dzhankoy
# Processing Record 9 of Set 11 | gibraleon
# Processing Record 10 of Set 11 | aksarka
# Processing Record 11 of Set 11 | ye
# City not found. Skipping...
# Processing Record 12 of Set 11 | phangnga
# Processing Record 13 of Set 11 | beyneu
# Processing Record 14 of Set 11 | odesskoye
# Processing Record 15 of Set 11 | dayong
# Processing Record 16 of Set 11 | homer
# Processing Record 17 of Set 11 | tanout
# Processing Record 18 of Set 11 | springbok
# Processing Record 19 of Set 11 | sao joao da barra
# Processing Record 20 of Set 11 | yeppoon
# Processing Record 21 of Set 11 | mahon
# Processing Record 22 of Set 11 | goma
# Processing Record 23 of Set 11 | alpena
# Processing Record 24 of Set 11 | nemsova
# Processing Record 25 of Set 11 | swellendam
# Processing Record 26 of Set 11 | choix
# Processing Record 27 of Set 11 | rayon
# Processing Record 28 of Set 11 | menongue
# Processing Record 29 of Set 11 | vila
# Processing Record 30 of Set 11 | kuusamo
# Processing Record 31 of Set 11 | kirkuk
# Processing Record 32 of Set 11 | luderitz
# Processing Record 33 of Set 11 | powell
# Processing Record 34 of Set 11 | chicama
# Processing Record 35 of Set 11 | dodge city
# Processing Record 36 of Set 11 | khartoum
# Processing Record 37 of Set 11 | horsham
# Processing Record 38 of Set 11 | kiama
# Processing Record 39 of Set 11 | hatillo
# Processing Record 40 of Set 11 | mitsamiouli
# Processing Record 41 of Set 11 | samarai
# Processing Record 42 of Set 11 | pangai
# Processing Record 43 of Set 11 | kysyl-syr
# Processing Record 44 of Set 11 | coquimbo
# Processing Record 45 of Set 11 | dobson
# Processing Record 46 of Set 11 | rivers
# Processing Record 47 of Set 11 | indi
# Processing Record 48 of Set 11 | vaovai
# City not found. Skipping...
# Processing Record 49 of Set 11 | yalova
# Processing Record 50 of Set 11 | ahumada
# City not found. Skipping...
# Processing Record 1 of Set 12 | eenhana
# Processing Record 2 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 3 of Set 12 | pandan
# Processing Record 4 of Set 12 | wanning
# Processing Record 5 of Set 12 | provideniya
# Processing Record 6 of Set 12 | olinda
# Processing Record 7 of Set 12 | ilebo
# Processing Record 8 of Set 12 | sabang
# Processing Record 9 of Set 12 | karatau
# Processing Record 10 of Set 12 | rudnichnyy
# Processing Record 11 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 12 of Set 12 | inndyr
# Processing Record 13 of Set 12 | masindi
# Processing Record 14 of Set 12 | tulun
# Processing Record 15 of Set 12 | aksarayskiy
# Processing Record 16 of Set 12 | honningsvag
# Processing Record 17 of Set 12 | terrace bay
# Processing Record 18 of Set 12 | kavaratti
# Processing Record 19 of Set 12 | san ignacio
# Processing Record 20 of Set 12 | shelburne
# Processing Record 21 of Set 12 | palana
# Processing Record 22 of Set 12 | bilma
# Processing Record 23 of Set 12 | celestun
# Processing Record 24 of Set 12 | morgan city
# Processing Record 25 of Set 12 | taldan
# Processing Record 26 of Set 12 | karauzyak
# City not found. Skipping...
# Processing Record 27 of Set 12 | topolobampo
# Processing Record 28 of Set 12 | itaituba
# Processing Record 29 of Set 12 | inderborskiy
# City not found. Skipping...
# Processing Record 30 of Set 12 | ust-tsilma
# Processing Record 31 of Set 12 | beringovskiy
# Processing Record 32 of Set 12 | klaksvik
# Processing Record 33 of Set 12 | barguzin
# Processing Record 34 of Set 12 | yaan
# Processing Record 35 of Set 12 | kawalu
# Processing Record 36 of Set 12 | wamba
# Processing Record 37 of Set 12 | unguia
# Processing Record 38 of Set 12 | sable-sur-sarthe
# Processing Record 39 of Set 12 | vila velha
# Processing Record 40 of Set 12 | wagar
# Processing Record 41 of Set 12 | mwingi
# Processing Record 42 of Set 12 | nkhata bay
# Processing Record 43 of Set 12 | sorland
# Processing Record 44 of Set 12 | hasaki
# Processing Record 45 of Set 12 | miandrivazo
# Processing Record 46 of Set 12 | deputatskiy
# Processing Record 47 of Set 12 | aloleng
# Processing Record 48 of Set 12 | zilina
# Processing Record 49 of Set 12 | afgoye
# City not found. Skipping...
# Processing Record 50 of Set 12 | asyut
# Processing Record 1 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 2 of Set 13 | hirara
# Processing Record 3 of Set 13 | svetlogorsk
# Processing Record 4 of Set 13 | chara
# Processing Record 5 of Set 13 | the valley
# Processing Record 6 of Set 13 | altay
# Processing Record 7 of Set 13 | dicabisagan
# Processing Record 8 of Set 13 | paralia
# Processing Record 9 of Set 13 | kjopsvik
# Processing Record 10 of Set 13 | eisenhuttenstadt
# City not found. Skipping...
# Processing Record 11 of Set 13 | urumqi
# Processing Record 12 of Set 13 | marsaxlokk
# Processing Record 13 of Set 13 | kamiiso
# Processing Record 14 of Set 13 | bereda
# Processing Record 15 of Set 13 | shache
# Processing Record 16 of Set 13 | puli
# Processing Record 17 of Set 13 | sur
# Processing Record 18 of Set 13 | turan
# Processing Record 19 of Set 13 | japura
# Processing Record 20 of Set 13 | potsdam
# Processing Record 21 of Set 13 | campeche
# Processing Record 22 of Set 13 | tilichiki
# Processing Record 23 of Set 13 | udachnyy
# Processing Record 24 of Set 13 | rock springs
# Processing Record 25 of Set 13 | mitu
# Processing Record 26 of Set 13 | kenora
# Processing Record 27 of Set 13 | nakhodka
# Processing Record 28 of Set 13 | helena
# Processing Record 29 of Set 13 | callaguip
# Processing Record 30 of Set 13 | guelengdeng
# City not found. Skipping...
# Processing Record 31 of Set 13 | olafsvik
# Processing Record 32 of Set 13 | anadyr
# Processing Record 33 of Set 13 | placer
# Processing Record 34 of Set 13 | kurtamysh
# Processing Record 35 of Set 13 | harer
# Processing Record 36 of Set 13 | oudtshoorn
# Processing Record 37 of Set 13 | tabou
# Processing Record 38 of Set 13 | lillooet
# Processing Record 39 of Set 13 | ahipara
# Processing Record 40 of Set 13 | mana
# Processing Record 41 of Set 13 | arman
# Processing Record 42 of Set 13 | shkotovo-26
# City not found. Skipping...
# Processing Record 43 of Set 13 | new bern
# Processing Record 44 of Set 13 | vanimo
# Processing Record 45 of Set 13 | nikolayevsk-na-amure
# Processing Record 46 of Set 13 | copiapo
# Processing Record 47 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 48 of Set 13 | molinella
# Processing Record 49 of Set 13 | mineiros
# Processing Record 50 of Set 13 | palu
# Processing Record 1 of Set 14 | rawson
# Processing Record 2 of Set 14 | cape canaveral
# Processing Record 3 of Set 14 | laredo
# Processing Record 4 of Set 14 | harnosand
# Processing Record 5 of Set 14 | gijon
# Processing Record 6 of Set 14 | kabanjahe
# Processing Record 7 of Set 14 | brae
# Processing Record 8 of Set 14 | boden
# Processing Record 9 of Set 14 | dengzhou
# Processing Record 10 of Set 14 | masatepe
# Processing Record 11 of Set 14 | san-pedro
# Processing Record 12 of Set 14 | mount gambier
# Processing Record 13 of Set 14 | teruel
# Processing Record 14 of Set 14 | salalah
# Processing Record 15 of Set 14 | jalu
# Processing Record 16 of Set 14 | anderson
# Processing Record 17 of Set 14 | carlsbad
# Processing Record 18 of Set 14 | krasnomayskiy
# Processing Record 19 of Set 14 | san juan de uraba
# Processing Record 20 of Set 14 | anshun
# Processing Record 21 of Set 14 | harqalah
# Processing Record 22 of Set 14 | aporawan
# City not found. Skipping...
# Processing Record 23 of Set 14 | huatulco
# Processing Record 24 of Set 14 | tamalameque
# Processing Record 25 of Set 14 | boma
# Processing Record 26 of Set 14 | crab hill
# City not found. Skipping...
# Processing Record 27 of Set 14 | tiruvalla
# Processing Record 28 of Set 14 | moranbah
# Processing Record 29 of Set 14 | laibin
# Processing Record 30 of Set 14 | robertsport
# Processing Record 31 of Set 14 | suntar
# Processing Record 32 of Set 14 | armacao dos buzios
# City not found. Skipping...
# Processing Record 33 of Set 14 | owando
# Processing Record 34 of Set 14 | sisimiut
# Processing Record 35 of Set 14 | banda aceh
# Processing Record 36 of Set 14 | la asuncion
# Processing Record 37 of Set 14 | san policarpo
# Processing Record 38 of Set 14 | sovetskiy
# Processing Record 39 of Set 14 | vung tau
# Processing Record 40 of Set 14 | qaqortoq
# Processing Record 41 of Set 14 | endicott
# Processing Record 42 of Set 14 | kloulklubed
# Processing Record 43 of Set 14 | bengkulu
# Processing Record 44 of Set 14 | viransehir
# Processing Record 45 of Set 14 | traiguen
# Processing Record 46 of Set 14 | mathathane
# Processing Record 47 of Set 14 | chiang khong
# Processing Record 48 of Set 14 | poya
# Processing Record 49 of Set 14 | henties bay
# Processing Record 50 of Set 14 | morwa
# Processing Record 1 of Set 15 | keshorai patan
# Processing Record 2 of Set 15 | pacific grove
# Processing Record 3 of Set 15 | la ciotat
# Processing Record 4 of Set 15 | kargil
# Processing Record 5 of Set 15 | grand-santi
# Processing Record 6 of Set 15 | souillac
# Processing Record 7 of Set 15 | wajir
# Processing Record 8 of Set 15 | manjacaze
# Processing Record 9 of Set 15 | adet
# Processing Record 10 of Set 15 | muli
# Processing Record 11 of Set 15 | palabuhanratu
# City not found. Skipping...
# Processing Record 12 of Set 15 | hofn
# Processing Record 13 of Set 15 | loknya
# Processing Record 14 of Set 15 | susurluk
# Processing Record 15 of Set 15 | omsukchan
# Processing Record 16 of Set 15 | dieburg
# Processing Record 17 of Set 15 | alta floresta
# Processing Record 18 of Set 15 | luwuk
# Processing Record 19 of Set 15 | yurimaguas
# Processing Record 20 of Set 15 | venustiano carranza
# Processing Record 21 of Set 15 | goba
# Processing Record 22 of Set 15 | matay
# Processing Record 23 of Set 15 | mizan teferi
# Processing Record 24 of Set 15 | ossora
# Processing Record 25 of Set 15 | blackwater
# Processing Record 26 of Set 15 | bonanza
# Processing Record 27 of Set 15 | lodwar
# Processing Record 28 of Set 15 | agadir
# Processing Record 29 of Set 15 | imeni babushkina
# Processing Record 30 of Set 15 | lohja
# Processing Record 31 of Set 15 | cacequi
# Processing Record 32 of Set 15 | kremenchuk
# Processing Record 33 of Set 15 | patzun
# Processing Record 34 of Set 15 | forestville
# Processing Record 35 of Set 15 | maloh
# Processing Record 36 of Set 15 | kuala pilah
# Processing Record 37 of Set 15 | taga dzong
# City not found. Skipping...
# Processing Record 38 of Set 15 | saravena
# Processing Record 39 of Set 15 | belyy yar
# Processing Record 40 of Set 15 | tukrah
# Processing Record 41 of Set 15 | rabo de peixe
# Processing Record 42 of Set 15 | berlevag
# Processing Record 43 of Set 15 | dennery
# Processing Record 44 of Set 15 | baruun-urt
# Processing Record 45 of Set 15 | seymchan
# Processing Record 46 of Set 15 | inhambane
# Processing Record 47 of Set 15 | nefteyugansk
# Processing Record 48 of Set 15 | ajdabiya
# Processing Record 49 of Set 15 | wadi musa
# Processing Record 50 of Set 15 | black forest
# Processing Record 1 of Set 16 | rio grande
# Processing Record 2 of Set 16 | jibuti
# Processing Record 3 of Set 16 | sefophe
# Processing Record 4 of Set 16 | linqiong
# Processing Record 5 of Set 16 | porto santo
# Processing Record 6 of Set 16 | genhe
# Processing Record 7 of Set 16 | mananjary
# Processing Record 8 of Set 16 | piney green
# Processing Record 9 of Set 16 | hihya
# Processing Record 10 of Set 16 | margate
# Processing Record 11 of Set 16 | agirish
# Processing Record 12 of Set 16 | teguldet
# Processing Record 13 of Set 16 | rio cuarto
# Processing Record 14 of Set 16 | severomuysk
# Processing Record 15 of Set 16 | issaquah
# Processing Record 16 of Set 16 | junin
# Processing Record 17 of Set 16 | dauphin
# Processing Record 18 of Set 16 | groningen
# Processing Record 19 of Set 16 | yuty
# Processing Record 20 of Set 16 | paracuru
# Processing Record 21 of Set 16 | kutum
# Processing Record 22 of Set 16 | qasigiannguit
# Processing Record 23 of Set 16 | nieuw amsterdam
# Processing Record 24 of Set 16 | florida
# Processing Record 25 of Set 16 | puerto ayacucho
# Processing Record 26 of Set 16 | kirksville
# Processing Record 27 of Set 16 | manoel urbano
# Processing Record 28 of Set 16 | ambunti
# Processing Record 29 of Set 16 | buta
# Processing Record 30 of Set 16 | naudero
# Processing Record 31 of Set 16 | broome
# Processing Record 32 of Set 16 | kapustin yar-1
# City not found. Skipping...
# Processing Record 33 of Set 16 | nouakchott
# Processing Record 34 of Set 16 | verkhnyaya inta
# Processing Record 35 of Set 16 | aguadilla
# Processing Record 36 of Set 16 | yanam
# Processing Record 37 of Set 16 | kamenka
# Processing Record 38 of Set 16 | grindavik
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 720

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Nanortalik  60.1432  -45.2371     23.14        75         100
# 1        Puerto Ayora  -0.7393  -90.3518     68.56        96          99
# 2             Rikitea -23.1203 -134.9692     77.92        75          65
# 3               Kapaa  22.0752 -159.3190     80.58        72          74
# 4            Onomichi  34.4167  133.2000     49.89        56           9
# 5  Comodoro Rivadavia -45.8667  -67.5000     55.26        88           0
# 6             Mataura -46.1927  168.8643     64.47        33          12
# 7          Bredasdorp -34.5322   20.0403     61.92        88         100
# 8             Pangody  65.8500   74.4859    -28.71        97          11
# 9              Zhuhai  22.2769  113.5678     65.05        68          20
#
#    Wind Speed Country Current Description
# 0        8.93      GL     overcast clouds
# 1        4.00      EC     overcast clouds
# 2        7.58      PF       broken clouds
# 3        5.01      US          light rain
# 4        7.58      JP           clear sky
# 5        5.75      AR           clear sky
# 6        4.45      NZ          few clouds
# 7        3.44      ZA     overcast clouds
# 8        5.17      RU          few clouds
# 9       23.02      CN          few clouds

# %%
#Create the output file (CSV)
output_data_file = "WeatherPy_Database.csv"

#Export the City_Data unto a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
